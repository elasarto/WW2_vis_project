# %%
# Dependencies
import pandas as pd
import numpy as np
import os

# %%
csv1 = "total_population.csv"
csv2 = "total_projected_pop.csv"
csv3 = "pop_density.csv"
csv4 = "total_gdp.csv"
csv5 = "life_expectancy.csv"

# %%
population_df = pd.read_csv(csv1)
projected_pop_df = pd.read_csv(csv2)
density_df = pd.read_csv(csv3)
gdp_df = pd.read_csv(csv4)
life_expect_df = pd.read_csv(csv5)

# %%
population_df.head()
# Out:
#         total_population  year_1800 year_1810 year_1820 year_1830 year_1840  \
# 0            Afghanistan    3280000   3280000   3323519   3448982   3625022
# 1  Akrotiri and Dhekelia        NaN       NaN       NaN       NaN       NaN
# 2                Albania    410,445    423591    438671    457234    478227
# 3                Algeria  2,503,218   2595056   2713079   2880355   3082721
# 4         American Samoa      8,170      8156      8142      8128      8114
#
#   year_1850 year_1860 year_1870 year_1880    ...    year_2006 year_2007  \
# 0   3810047   3973968   4169690   4419695    ...     25183615  25877544
# 1       NaN       NaN       NaN       NaN    ...        15700     15700
# 2    506889    552800    610036    672544    ...      3050741   3010849
# 3   3299305   3536468   3811028   4143163    ...     33749328  34261971
# 4      7958      7564      7057      6582    ...        58648     57904
#
#   year_2008 year_2009 year_2010 year_2011 year_2012 year_2013 year_2014  \
# ...

# %%
# year_1920
# year_1930
# year_1940
# year_1950
# year_1951
# year_1952
# year_1953
# year_1954
# year_1955

# %%
selected_pop = population_df[['total_population','year_1920', 'year_1930', 'year_1940', 'year_1950', 'year_1951', 'year_1952', 'year_1953', 'year_1954', 'year_1955']]
selected_pop.head()
# Out:
#         total_population year_1920 year_1930 year_1940 year_1950 year_1951  \
# 0            Afghanistan   5813814   6394908   7034081   7752118   7839426
# 1  Akrotiri and Dhekelia       NaN       NaN       NaN     10661     10737
# 2                Albania    963956   1015991   1123210   1263171   1287499
# 3                Algeria   6063800   6876190   7797418   8872247   9039913
# 4         American Samoa      8173     10081     13135     18937     19295
#
#   year_1952  year_1953 year_1954 year_1955
# 0   7934798  8,038,312   8150037   8270024
# 1     10813     10,889     10966     11043
# 2   1316086  1,348,097   1382881   1419969
# 3   9216395  9,405,445   9609507   9829717
# 4     19543     19,683     19729     19706

# %%
pop_df = selected_pop.rename(columns={'total_population': 'country'})
pop_df.head()
# Out:
#                  country year_1920 year_1930 year_1940 year_1950 year_1951  \
# 0            Afghanistan   5813814   6394908   7034081   7752118   7839426
# 1  Akrotiri and Dhekelia       NaN       NaN       NaN     10661     10737
# 2                Albania    963956   1015991   1123210   1263171   1287499
# 3                Algeria   6063800   6876190   7797418   8872247   9039913
# 4         American Samoa      8173     10081     13135     18937     19295
#
#   year_1952  year_1953 year_1954 year_1955
# 0   7934798  8,038,312   8150037   8270024
# 1     10813     10,889     10966     11043
# 2   1316086  1,348,097   1382881   1419969
# 3   9216395  9,405,445   9609507   9829717
# 4     19543     19,683     19729     19706

# %%
projected_pop_df.head()
# Out:
#         Total population 1086 1100 1290 1300 1348 1349 1351 1377 1413  \
# 0               Abkhazia  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1            Afghanistan  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2  Akrotiri and Dhekelia  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3                Albania  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4                Algeria  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#       ...             2006        2007        2008        2009        2010  \
# 0     ...              NaN         NaN         NaN         NaN         NaN
# 1     ...       28,420,974  29,145,841  29,839,994  30,577,756  31,411,743
# 2     ...              NaN         NaN      15,700         NaN         NaN
# 3     ...        3,156,607   3,169,665   3,181,397   3,192,723   3,204,284
# 4     ...       33,391,954  33,906,605  34,428,028  34,950,168  35,468,208
#
#          2011        2012        2013        2050         2100
# ...

# %%
projected_pop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Columns: 252 entries, Total population to 2100
# dtypes: float64(1), object(251)
# memory usage: 512.0+ KB

# %%
projected = projected_pop_df.loc[:, "1920": "1955"]
projected.head()
# Out:
#       1920     1921     1922     1923     1924     1925     1926     1927  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3  932,000  937,000  942,000  947,000  952,000  956,000  962,000  967,000
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#       1928     1929    ...           1946       1947       1948       1949  \
# 0      NaN      NaN    ...            NaN        NaN        NaN        NaN
# 1      NaN      NaN    ...            NaN        NaN        NaN        NaN
# 2      NaN      NaN    ...            NaN        NaN        NaN        NaN
# 3  972,000  977,000    ...      1,154,000  1,175,000  1,192,000  1,209,000
# 4      NaN      NaN    ...            NaN        NaN        NaN        NaN
#
#         1950       1951       1952       1953       1954       1955
# ...

# %%
country = projected_pop_df.iloc[:, 0]
country.head()
# Out:
# 0                 Abkhazia
# 1              Afghanistan
# 2    Akrotiri and Dhekelia
# 3                  Albania
# 4                  Algeria
# Name: Total population, dtype: object

# %%
country = projected_pop_df.loc[:, ["Total population"]]
country.head()
# Out:
#         Total population
# 0               Abkhazia
# 1            Afghanistan
# 2  Akrotiri and Dhekelia
# 3                Albania
# 4                Algeria

# %%
country = country.rename(columns={"Total population": 'country'}) 
country.head()
# Out:
#                  country
# 0               Abkhazia
# 1            Afghanistan
# 2  Akrotiri and Dhekelia
# 3                Albania
# 4                Algeria

# %%
final_pop = pd.concat([country, projected], axis=1)
final_pop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-d21eab761cce> in <module>()
# ----> 1 final_pop = pd.concat([country, projected], axis=1)
#       2 final_pop
#
# NameError: name 'projected' is not defined

# %%
final_pop.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-b3f9c81ca74e> in <module>()
# ----> 1 final_pop.columns
#
# NameError: name 'final_pop' is not defined

# %%
final_pop = final_pop.rename(columns={'1920':"year_1920", '1921':"year_1921", '1922':"year_1922", '1923':"year_1923", '1924':"year_1924", 
                                      '1925':"year_1925", '1926':"year_1926",'1927':"year_1927",'1928':"year_1928", '1929':"year_1929", '1930':"year_1930", '1931':"year_1931", '1932':"year_1932", 
                                      '1933':"year_1933", '1934':"year_1934", '1935':"year_1935",'1936':"year_1936", '1937':"year_1937", '1938':"year_1938", '1939':"year_1939", 
                                      '1940':"year_1940", '1941':"year_1941", '1942':"year_1942", '1943':"year_1943", '1944':"year_1944",'1945':"year_1945", '1946':"year_1946", '1947':"year_1947", 
                                      '1948':"year_1948", '1949':"year_1949", '1950':"year_1950", '1951':"year_1951", '1952':"year_1952", '1953':"year_1953",'1954':"year_1954", '1955':"year_1955"}) 
final_pop.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-ab44c162d6cf> in <module>()
# ----> 1 final_pop = final_pop.rename(columns={'1920':"year_1920", '1921':"year_1921", '1922':"year_1922", '1923':"year_1923", '1924':"year_1924",
#       2                                       '1925':"year_1925", '1926':"year_1926",'1927':"year_1927",'1928':"year_1928", '1929':"year_1929", '1930':"year_1930", '1931':"year_1931", '1932':"year_1932",
#       3                                       '1933':"year_1933", '1934':"year_1934", '1935':"year_1935",'1936':"year_1936", '1937':"year_1937", '1938':"year_1938", '1939':"year_1939",
#       4                                       '1940':"year_1940", '1941':"year_1941", '1942':"year_1942", '1943':"year_1943", '1944':"year_1944",'1945':"year_1945", '1946':"year_1946", '1947':"year_1947",
# ...

# %%
len(final_pop.columns)
# Out:
# 37

# %%
density_df.head()
# Out:
#   Population density (per square km)    1950    1951    1952    1953    1954  \
# 0                           Abkhazia     NaN     NaN     NaN     NaN     NaN
# 1                        Afghanistan  12.501  12.693  12.893  13.101  13.318
# 2              Akrotiri and Dhekelia     NaN     NaN     NaN     NaN     NaN
# 3                            Albania  42.264  43.132  44.153  45.309  46.586
# 4                            Algeria   3.675   3.759   3.838   3.916   3.995
#
#      1955    1956    1957    1958   ...        2001     2002     2003  \
# 0     NaN     NaN     NaN     NaN   ...         NaN      NaN      NaN
# 1  13.545  13.781  14.028  14.285   ...      36.310   37.786   39.379
# 2     NaN     NaN     NaN     NaN   ...         NaN      NaN      NaN
# 3  47.968  49.444  50.999  52.622   ...     107.047  107.478  108.067
# 4   4.079   4.167   4.258   4.352   ...      13.008   13.201   13.399
#
#       2004     2005     2006     2007     2008     2009     2010
# ...

# %%
density = density_df.loc[:, "1950": "1955"]
density.head()
# Out:
#      1950    1951    1952    1953    1954    1955
# 0     NaN     NaN     NaN     NaN     NaN     NaN
# 1  12.501  12.693  12.893  13.101  13.318  13.545
# 2     NaN     NaN     NaN     NaN     NaN     NaN
# 3  42.264  43.132  44.153  45.309  46.586  47.968
# 4   3.675   3.759   3.838   3.916   3.995   4.079

# %%
country4 = density_df.loc[:, ["Population density (per square km)"]]
country4.head()
# Out:
#   Population density (per square km)
# 0                           Abkhazia
# 1                        Afghanistan
# 2              Akrotiri and Dhekelia
# 3                            Albania
# 4                            Algeria

# %%
country4 = country4.rename(columns={"Population density (per square km)": 'country'}) 
country4.head()
# Out:
#                  country
# 0               Abkhazia
# 1            Afghanistan
# 2  Akrotiri and Dhekelia
# 3                Albania
# 4                Algeria

# %%
density_final = pd.concat([country4, density], axis=1)
density_final.head()
# Out:
#                  country    1950    1951    1952    1953    1954    1955
# 0               Abkhazia     NaN     NaN     NaN     NaN     NaN     NaN
# 1            Afghanistan  12.501  12.693  12.893  13.101  13.318  13.545
# 2  Akrotiri and Dhekelia     NaN     NaN     NaN     NaN     NaN     NaN
# 3                Albania  42.264  43.132  44.153  45.309  46.586  47.968
# 4                Algeria   3.675   3.759   3.838   3.916   3.995   4.079

# %% [markdown]
# ####

# %%
density_final = density_final.rename(columns={'1950':"year_1950", '1951':"year_1951", '1952':"year_1952", '1953':"year_1953",'1954':"year_1954", '1955':"year_1955"}) 
density_final.head()
# Out:
#                  country  year_1950  year_1951  year_1952  year_1953  \
# 0               Abkhazia        NaN        NaN        NaN        NaN
# 1            Afghanistan     12.501     12.693     12.893     13.101
# 2  Akrotiri and Dhekelia        NaN        NaN        NaN        NaN
# 3                Albania     42.264     43.132     44.153     45.309
# 4                Algeria      3.675      3.759      3.838      3.916
#
#    year_1954  year_1955
# 0        NaN        NaN
# 1     13.318     13.545
# 2        NaN        NaN
# 3     46.586     47.968
# 4      3.995      4.079

# %%
gdp_df.head()
# Out:
#   GDP per capita PPP, with projections  1764  1765  1766  1767  1768  1769  \
# 0                             Abkhazia   NaN   NaN   NaN   NaN   NaN   NaN
# 1                          Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN
# 2                Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN
# 3                              Albania   NaN   NaN   NaN   NaN   NaN   NaN
# 4                              Algeria   NaN   NaN   NaN   NaN   NaN   NaN
#
#    1770  1771  1772     ...              2009         2010         2011  \
# 0   NaN   NaN   NaN     ...               NaN          NaN          NaN
# 1   NaN   NaN   NaN     ...       1154.859365  1214.613653  1261.354184
# 2   NaN   NaN   NaN     ...               NaN          NaN          NaN
# 3   NaN   NaN   NaN     ...       6550.896164  6746.445312  6914.267317
# 4   NaN   NaN   NaN     ...       6173.729741  6300.648214  6354.640523
#
#           2012         2013         2014         2015         2016  \
# ...

# %%
gdp = gdp_df.loc[:, "1914": "1955"]
gdp.head()
# Out:
#    1914  1915  1916  1917  1918  1919  1920  1921  1922  1923     ...       \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN     ...
#
#    1946  1947  1948  1949         1950         1951         1952         1953  \
# 0   NaN   NaN   NaN   NaN          NaN          NaN          NaN          NaN
# 1   NaN   NaN   NaN   NaN   757.318795   766.752197   779.445314   812.856280
# 2   NaN   NaN   NaN   NaN          NaN          NaN          NaN          NaN
# 3   NaN   NaN   NaN   NaN  1532.353932  1598.492750  1601.056136  1665.794737
# 4   NaN   NaN   NaN   NaN  2429.213704  2397.531111  2449.008185  2436.339950
#
#           1954         1955
# 0          NaN          NaN
# ...

# %%
country3 = gdp_df.loc[:, ["GDP per capita PPP, with projections"]]
country3.head()
# Out:
#   GDP per capita PPP, with projections
# 0                             Abkhazia
# 1                          Afghanistan
# 2                Akrotiri and Dhekelia
# 3                              Albania
# 4                              Algeria

# %%
country3 = country3.rename(columns={"GDP per capita PPP, with projections": 'country'}) 
country3.head()
# Out:
#                  country
# 0               Abkhazia
# 1            Afghanistan
# 2  Akrotiri and Dhekelia
# 3                Albania
# 4                Algeria

# %%
gdp_final = pd.concat([country3, gdp], axis=1)
gdp_final
# Out:
#                           country         1914         1915         1916  \
# 0                        Abkhazia          NaN          NaN          NaN
# 1                     Afghanistan          NaN          NaN          NaN
# 2           Akrotiri and Dhekelia          NaN          NaN          NaN
# 3                         Albania          NaN          NaN          NaN
# 4                         Algeria          NaN          NaN          NaN
# 5                  American Samoa          NaN          NaN          NaN
# 6                         Andorra          NaN          NaN          NaN
# 7                          Angola          NaN          NaN          NaN
# 8                        Anguilla          NaN          NaN          NaN
# 9             Antigua and Barbuda          NaN          NaN          NaN
# 10                      Argentina  4091.984842  3949.966432  3767.939429
# 11                        Armenia   703.883486   722.802980   700.000000
# ...

# %%
gdp_final.columns
# Out:
# Index(['country', '1914', '1915', '1916', '1917', '1918', '1919', '1920',
#        '1921', '1922', '1923', '1924', '1925', '1926', '1927', '1928', '1929',
#        '1930', '1931', '1932', '1933', '1934', '1935', '1936', '1937', '1938',
#        '1939', '1940', '1941', '1942', '1943', '1944', '1945', '1946', '1947',
#        '1948', '1949', '1950', '1951', '1952', '1953', '1954', '1955'],
#       dtype='object')

# %%
gdp_final = gdp_final.rename(columns={'1914':"year_1914",'1915':"year_1915",'1916':"year_1916",'1917':"year_1917",'1918':"year_1918",'1919':"year_1919",'1920':"year_1920", '1921':"year_1921", '1922':"year_1922", '1923':"year_1923", '1924':"year_1924", 
                                      '1925':"year_1925", '1926':"year_1926",'1927':"year_1927",'1928':"year_1928", '1929':"year_1929", '1930':"year_1930", '1931':"year_1931", '1932':"year_1932", 
                                      '1933':"year_1933", '1934':"year_1934", '1935':"year_1935",'1936':"year_1936", '1937':"year_1937", '1938':"year_1938", '1939':"year_1939", 
                                      '1940':"year_1940", '1941':"year_1941", '1942':"year_1942", '1943':"year_1943", '1944':"year_1944",'1945':"year_1945", '1946':"year_1946", '1947':"year_1947", 
                                      '1948':"year_1948", '1949':"year_1949", '1950':"year_1950", '1951':"year_1951", '1952':"year_1952", '1953':"year_1953",'1954':"year_1954", '1955':"year_1955"}) 
gdp_final.head()
# Out:
#                  country  year_1914  year_1915  year_1916  year_1917  \
# 0               Abkhazia        NaN        NaN        NaN        NaN
# 1            Afghanistan        NaN        NaN        NaN        NaN
# 2  Akrotiri and Dhekelia        NaN        NaN        NaN        NaN
# 3                Albania        NaN        NaN        NaN        NaN
# 4                Algeria        NaN        NaN        NaN        NaN
#
#    year_1918  year_1919  year_1920  year_1921  year_1922     ...       \
# 0        NaN        NaN        NaN        NaN        NaN     ...
# 1        NaN        NaN        NaN        NaN        NaN     ...
# 2        NaN        NaN        NaN        NaN        NaN     ...
# 3        NaN        NaN        NaN        NaN        NaN     ...
# 4        NaN        NaN        NaN        NaN        NaN     ...
#
#    year_1946  year_1947  year_1948  year_1949    year_1950    year_1951  \
# 0        NaN        NaN        NaN        NaN          NaN          NaN
# ...

# %%
len(gdp_final.columns)
# Out:
# 43

# %%
life_expect_df.head()
# Out:
#   Life expectancy with projections  1765  1766  1767  1768  1769  1770  1771  \
# 0                      Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1                          Albania   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2                          Algeria   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3                   American Samoa   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4                          Andorra   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    1772  1773   ...      2009    2010    2011    2012    2013    2014    2015  \
# 0   NaN   NaN   ...    59.124  59.612  60.079  60.524  60.947  61.347  61.726
# 1   NaN   NaN   ...    76.598  76.780  76.979  77.185  77.392  77.600  77.807
# 2   NaN   NaN   ...    70.477  70.615  70.747  70.874  71.000  71.123  71.246
# 3   NaN   NaN   ...       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4   NaN   NaN   ...       NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#      2025    2050    2099
# ...

# %%
life_exp = life_expect_df.loc[:, "1914": "1955"]
life_exp.head()
# Out:
#        1914       1915       1916       1917       1918       1919     1920  \
# 0  27.04288  27.032633  27.022387  27.012140   7.045063  26.991647  26.9814
# 1  35.40000  35.400000  35.400000  35.400000  19.427932  35.400000  35.4000
# 2  29.16060  28.657200  28.287837  28.287837  22.056668  28.287837  27.5000
# 3       NaN        NaN        NaN        NaN        NaN        NaN      NaN
# 4       NaN        NaN        NaN        NaN        NaN        NaN      NaN
#
#         1921       1922      1923   ...         1946       1947       1948  \
# 0  26.971153  26.960907  26.95066   ...    26.714987  26.704740  26.694493
# 1  35.400000  35.400000  35.40000   ...    50.000000  51.506571  52.401381
# 2  27.500000  27.216000  29.62400   ...    32.000000  35.000000  37.800000
# 3        NaN        NaN       NaN   ...          NaN        NaN        NaN
# 4        NaN        NaN       NaN   ...          NaN        NaN        NaN
#
# ...

# %%
country2 = life_expect_df.loc[:, ["Life expectancy with projections"]]
country2.head()
# Out:
#   Life expectancy with projections
# 0                      Afghanistan
# 1                          Albania
# 2                          Algeria
# 3                   American Samoa
# 4                          Andorra

# %%
country2 = country2.rename(columns={"Life expectancy with projections": 'country'}) 
country2.head()
# Out:
#           country
# 0     Afghanistan
# 1         Albania
# 2         Algeria
# 3  American Samoa
# 4         Andorra

# %%
life_exp_final = pd.concat([country2, life_exp], axis=1)
life_exp_final
# Out:
#                       country       1914       1915       1916       1917  \
# 0                 Afghanistan  27.042880  27.032633  27.022387  27.012140
# 1                     Albania  35.400000  35.400000  35.400000  35.400000
# 2                     Algeria  29.160600  28.657200  28.287837  28.287837
# 3              American Samoa        NaN        NaN        NaN        NaN
# 4                     Andorra        NaN        NaN        NaN        NaN
# 5                      Angola  26.980000  26.980000  26.980000  26.980000
# 6                    Anguilla        NaN        NaN        NaN        NaN
# 7         Antigua and Barbuda  33.536000  33.536000  33.536000  33.536000
# 8                   Argentina  45.660000  46.200000  47.000000  47.800000
# 9                     Armenia  39.195000  38.795000  38.795000  35.795000
# 10                      Aruba  34.419000  34.419000  34.419000  34.419000
# 11                  Australia  57.335490  57.864706  58.393922  58.923137
# ...

# %%
life_exp_final.columns
# Out:
# Index(['country', '1914', '1915', '1916', '1917', '1918', '1919', '1920',
#        '1921', '1922', '1923', '1924', '1925', '1926', '1927', '1928', '1929',
#        '1930', '1931', '1932', '1933', '1934', '1935', '1936', '1937', '1938',
#        '1939', '1940', '1941', '1942', '1943', '1944', '1945', '1946', '1947',
#        '1948', '1949', '1950', '1951', '1952', '1953', '1954', '1955'],
#       dtype='object')

# %%
len(life_exp_final.columns)
# Out:
# 43

# %%
life_exp_final = life_exp_final.rename(columns={'1914':"year_1914",'1915':"year_1915",'1916':"year_1916",'1917':"year_1917",'1918':"year_1918",'1919':"year_1919",'1920':"year_1920", '1921':"year_1921", '1922':"year_1922", '1923':"year_1923", '1924':"year_1924", 
                                      '1925':"year_1925", '1926':"year_1926",'1927':"year_1927",'1928':"year_1928", '1929':"year_1929", '1930':"year_1930", '1931':"year_1931", '1932':"year_1932", 
                                      '1933':"year_1933", '1934':"year_1934", '1935':"year_1935",'1936':"year_1936", '1937':"year_1937", '1938':"year_1938", '1939':"year_1939", 
                                      '1940':"year_1940", '1941':"year_1941", '1942':"year_1942", '1943':"year_1943", '1944':"year_1944",'1945':"year_1945", '1946':"year_1946", '1947':"year_1947", 
                                      '1948':"year_1948", '1949':"year_1949", '1950':"year_1950", '1951':"year_1951", '1952':"year_1952", '1953':"year_1953",'1954':"year_1954", '1955':"year_1955"}) 
life_exp_final.head()
# Out:
#           country  year_1914  year_1915  year_1916  year_1917  year_1918  \
# 0     Afghanistan   27.04288  27.032633  27.022387  27.012140   7.045063
# 1         Albania   35.40000  35.400000  35.400000  35.400000  19.427932
# 2         Algeria   29.16060  28.657200  28.287837  28.287837  22.056668
# 3  American Samoa        NaN        NaN        NaN        NaN        NaN
# 4         Andorra        NaN        NaN        NaN        NaN        NaN
#
#    year_1919  year_1920  year_1921  year_1922    ...      year_1946  \
# 0  26.991647    26.9814  26.971153  26.960907    ...      26.714987
# 1  35.400000    35.4000  35.400000  35.400000    ...      50.000000
# 2  28.287837    27.5000  27.500000  27.216000    ...      32.000000
# 3        NaN        NaN        NaN        NaN    ...            NaN
# 4        NaN        NaN        NaN        NaN    ...            NaN
#
#    year_1947  year_1948  year_1949  year_1950  year_1951  year_1952  \
# ...

# %%
population_csv = "population_final_cleaned.csv"
final_pop.to_csv(population_csv, encoding="utf-8", index=False)

# %%
gdp_csv = "gdp_final_cleaned.csv"
gdp_final.to_csv(gdp_csv, encoding="utf-8", index=False)

# %%
life_exp_csv = "life_exp_final_cleaned.csv"
life_exp_final.to_csv(life_exp_csv, encoding="utf-8", index=False)

# %%
density_csv = "density_final_cleaned.csv"
density_final.to_csv(density_csv, encoding="utf-8", index=False)

# %%
final_pop.dtypes
# Out:
# country      object
# year_1920    object
# year_1921    object
# year_1922    object
# year_1923    object
# year_1924    object
# year_1925    object
# year_1926    object
# year_1927    object
# year_1928    object
# year_1929    object
# year_1930    object
# year_1931    object
# year_1932    object
# year_1933    object
# year_1934    object
# year_1935    object
# year_1936    object
# year_1937    object
# year_1938    object
# year_1939    object
# year_1940    object
# year_1941    object
# year_1942    object
# year_1943    object
# year_1944    object
# year_1945    object
# year_1946    object
# year_1947    object
# year_1948    object
# year_1949    object
# year_1950    object
# year_1951    object
# year_1952    object
# year_1953    object
# year_1954    object
# year_1955    object
# dtype: object

# %%
# final_pop.fillna(0, inplace=True)

for col in final_pop.columns[1:]:
    final_pop[col] = final_pop[col].str.replace(',','')

final_pop.head()
# Out:
#                  country year_1920 year_1921 year_1922 year_1923 year_1924  \
# 0               Abkhazia       NaN       NaN       NaN       NaN       NaN
# 1            Afghanistan       NaN       NaN       NaN       NaN       NaN
# 2  Akrotiri and Dhekelia       NaN       NaN       NaN       NaN       NaN
# 3                Albania    932000    937000    942000    947000    952000
# 4                Algeria       NaN       NaN       NaN       NaN       NaN
#
#   year_1925 year_1926 year_1927 year_1928    ...    year_1946 year_1947  \
# 0       NaN       NaN       NaN       NaN    ...          NaN       NaN
# 1       NaN       NaN       NaN       NaN    ...          NaN       NaN
# 2       NaN       NaN       NaN       NaN    ...          NaN       NaN
# 3    956000    962000    967000    972000    ...      1154000   1175000
# 4       NaN       NaN       NaN       NaN    ...          NaN       NaN
#
#   year_1948 year_1949 year_1950 year_1951 year_1952 year_1953 year_1954  \
# ...

# %%
population_csv = "population_final_cleaned.csv"
final_pop.to_csv(population_csv, encoding="utf-8", index=False)
